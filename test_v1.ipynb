# %% [markdown]
# # stocklist

# %% [markdown]
# ## abstracks

# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print('version: ', sys.version)
# Out:
# version:  3.8.8 (default, Feb 24 2021, 21:46:12)
# [GCC 7.3.0]

# %%
import tushare as ts
import akshare as ak
import baostock as bt

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
def init(flag='tu'):
    if flag == 'tu':
        pro = ts.pro_api()
        return pro
    else:
        pass

# %%
def get_stock_list(flag='tu'):
    '''
    '''
    if flag == 'tu':
        df = ts.get_stock_basics()
        return df
    elif flag == 'ts':
        pass
    elif flag == 'ak':
        sh_df = ak.stock_sse_summary()
#         sz_df = ak.stock_szse_summary(date="20201231")
#         return sh_df, sz_df
        return sh_df
    else:
        pass

# %%
df = ak.stock_info_a_code_name()
# Out:
# /home/intellif/anaconda3/envs/stockv2/lib/python3.8/site-packages/akshare/stock/stock_info.py:33: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   temp_df = pd.read_excel(BytesIO(r.content), engine="xlrd")

# %%
df
# Out:
#         code   name
# 0     000001   平安银行
# 1     000002  万  科Ａ
# 2     000004   国华网安
# 3     000005   世纪星源
# 4     000006   深振业Ａ
# ...      ...    ...
# 4234  688777   中控技术
# 4235  688788   科思科技
# 4236  688819   天能股份
# 4237  688981   中芯国际
# 4238  689009   九号公司
#
# [4239 rows x 2 columns]

# %%
@interact
def show_stock_list(row_range=(0, 4000, 30)):
    df = ak.stock_info_a_code_name()
    show_df = df[0:row_range]
    return show_df
# Out:
# interactive(children=(IntSlider(value=1980, description='row_range', max=4000, step=30), Output()), _dom_class…

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
# CurrentConfig.ONLINE_HOST
import pyecharts as pe
import pyecharts.charts
from pyecharts.charts import Bar
from pyecharts import options as opts
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-95d81b09fbbd> in <module>
# ----> 1 from pyecharts.globals import CurrentConfig, NotebookType
#       2 CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
#       3 # CurrentConfig.ONLINE_HOST
#       4 import pyecharts as pe
#       5 import pyecharts.charts
#
# ModuleNotFoundError: No module named 'pyecharts'

# %%
bar = (
    Bar()
    .add_xaxis(['衬衫', '毛衣', '领带'])
    .add_yaxis('商家A', [114, 55, 27])
    .add_yaxis('商家B', [57, 134, 137])
    .set_global_opts(title_opts=opts.TitleOpts('某商家场销售情况'))
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-5f89ef524735> in <module>
#       1 bar = (
# ----> 2     Bar()
#       3     .add_xaxis(['衬衫', '毛衣', '领带'])
#       4     .add_yaxis('商家A', [114, 55, 27])
#       5     .add_yaxis('商家B', [57, 134, 137])
#
# NameError: name 'Bar' is not defined

# %%
# bar.render_notebook()
bar.load_javascript()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-014a182e619a> in <module>
#       1 # bar.render_notebook()
# ----> 2 bar.load_javascript()
#
# NameError: name 'bar' is not defined

# %%
bar.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fc8263bd7096> in <module>
# ----> 1 bar.render_notebook()
#
# NameError: name 'bar' is not defined

# %%
# Enabling the `widget` backend.
# This requires jupyter-matplotlib a.k.a. ipympl.
# ipympl can be install via pip or conda.
# %matplotlib widget

import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
plt.plot(np.sin(np.linspace(0, 20, 100)));
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.canvas.toolbar_visible = False
fig.canvas.header_visible = False # Hide the Figure name at the top of the figure

# %%
fig.canvas.footer_visible = False

# %%
fig.canvas.resizable = False

# %%
# If true then scrolling while the mouse is over the canvas will not move the entire notebook
fig.canvas.capture_scroll = True

# %%
fig.canvas.toolbar_visible = True
display(fig.canvas)
# display(fig)  # or
# Out:
# Canvas(capture_scroll=True, footer_visible=False, header_visible=False, resizable=False, toolbar=Toolbar(tooli…

# %%
from beakerx import *
import pandas as pd
import mplfinance as mplf

# %%
df = pd.read_csv('/data2/store/code/001/database/dbdata/000017.SZ/2020/20200101--20201231--W--qfq.csv',index_col=0,parse_dates=True)
df.index.name = 'trade_date'
df.shape
df.head(3)
df.tail(3)
df['trade_date'] = pd.to_datetime(df['trade_date'])
df.index.name = 'trade_date'
df.set_index('trade_date')
df
# Out:
#               ts_code                    trade_date  close  open  high   low  \
# trade_date
# 0           000017.SZ 1970-01-01 00:00:00.020201231   2.41  2.43  2.46  2.37
# 1           000017.SZ 1970-01-01 00:00:00.020201225   2.44  2.55  2.56  2.39
# 2           000017.SZ 1970-01-01 00:00:00.020201218   2.54  2.50  2.71  2.49
# 3           000017.SZ 1970-01-01 00:00:00.020201211   2.50  2.55  2.65  2.47
# 4           000017.SZ 1970-01-01 00:00:00.020201204   2.57  2.50  2.65  2.42
# 5           000017.SZ 1970-01-01 00:00:00.020201127   2.52  2.72  2.72  2.50
# 6           000017.SZ 1970-01-01 00:00:00.020201120   2.74  2.62  2.90  2.57
# 7           000017.SZ 1970-01-01 00:00:00.020201113   2.60  2.53  2.64  2.49
# 8           000017.SZ 1970-01-01 00:00:00.020201106   2.49  2.48  2.52  2.38
# 9           000017.SZ 1970-01-01 00:00:00.020201030   2.48  2.67  2.69  2.47
# 10          000017.SZ 1970-01-01 00:00:00.020201023   2.70  2.53  2.71  2.50
# ...

# %%
mplf.plot(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-c8ac0fd289b7> in <module>
# ----> 1 mplf.plot(df)
#
# ~/anaconda3/lib/python3.8/site-packages/mplfinance/plotting.py in plot(data, **kwargs)
#     282     config['type'] = _get_valid_plot_types(config['type'])
#     283
# --> 284     dates,opens,highs,lows,closes,volumes = _check_and_prepare_data(data, config)
#     285
#     286     if config['type'] in VALID_PMOVE_TYPES and config['addplot'] is not None:
#
# ~/anaconda3/lib/python3.8/site-packages/mplfinance/_arg_validators.py in _check_and_prepare_data(data, config)
#      27
#      28     if not isinstance(data.index,pd.core.indexes.datetimes.DatetimeIndex):
# ---> 29         raise TypeError('Expect data.index as DatetimeIndex')
#      30
#      31     # We will not be fully case-insensitive (since Pandas columns as NOT case-insensitive)
#
# ...

# %%
df1 = pd.read_csv('/data2/store/code/001/database/dbdata/000017.SZ/2020/20200101--20201231--W--qfq.csv',index_col=0,parse_dates=True)
cols=['trade_date','open','high','low','close', 'vol']
df2=df1[cols]
# df2=df2.set_index('trade_date')
# df2.sort_index()

df2.index.name='trade_date'
df2.index = pd.DatetimeIndex(df2.index)
df2.sort_index()

new_columns = {'trade_date':'trade_date', 'open':'open', 'high':'high', 'low':'low', 'close':'close', 'vol':'volume'}
df2.rename(columns=new_columns, inplace=True)
df2
# Out:
#                                trade_date  open  high   low  close  \
# trade_date
# 1970-01-01 00:00:00.000000000    20201231  2.43  2.46  2.37   2.41
# 1970-01-01 00:00:00.000000001    20201225  2.55  2.56  2.39   2.44
# 1970-01-01 00:00:00.000000002    20201218  2.50  2.71  2.49   2.54
# 1970-01-01 00:00:00.000000003    20201211  2.55  2.65  2.47   2.50
# 1970-01-01 00:00:00.000000004    20201204  2.50  2.65  2.42   2.57
# 1970-01-01 00:00:00.000000005    20201127  2.72  2.72  2.50   2.52
# 1970-01-01 00:00:00.000000006    20201120  2.62  2.90  2.57   2.74
# 1970-01-01 00:00:00.000000007    20201113  2.53  2.64  2.49   2.60
# 1970-01-01 00:00:00.000000008    20201106  2.48  2.52  2.38   2.49
# 1970-01-01 00:00:00.000000009    20201030  2.67  2.69  2.47   2.48
# 1970-01-01 00:00:00.000000010    20201023  2.53  2.71  2.50   2.70
# 1970-01-01 00:00:00.000000011    20201016  2.49  2.57  2.49   2.52
# 1970-01-01 00:00:00.000000012    20201009  2.41  2.46  2.41   2.45
# ...

# %%
mc = mplf.make_marketcolors(up='r',down='g')
s  = mplf.make_mpf_style(marketcolors=mc,mavcolors=['#4f8a8b','#fbd46d','#87556f'])
# mplf.plot(df2, type='candle', volume=True, show_nontrading=True, figratio=(20,10), mav=(5,10,15),style=s)
mplf.plot(df2, type='candle', volume=True, figratio=(20,10), mav=(5,10,15), style=s)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from beakerx import *

# %%
df = pd.read_csv('/data2/store/code/001/database/dbdata/000017.SZ/2020/20200101--20201231--W--qfq.csv',index_col=0,parse_dates=True)

# %%
df
# Out:
#       ts_code  trade_date  close  open  high   low  pre_close  change  \
# 0   000017.SZ    20201231   2.41  2.43  2.46  2.37       2.44   -0.03
# 1   000017.SZ    20201225   2.44  2.55  2.56  2.39       2.54   -0.10
# 2   000017.SZ    20201218   2.54  2.50  2.71  2.49       2.50    0.04
# 3   000017.SZ    20201211   2.50  2.55  2.65  2.47       2.57   -0.07
# 4   000017.SZ    20201204   2.57  2.50  2.65  2.42       2.52    0.05
# 5   000017.SZ    20201127   2.52  2.72  2.72  2.50       2.74   -0.22
# 6   000017.SZ    20201120   2.74  2.62  2.90  2.57       2.60    0.14
# 7   000017.SZ    20201113   2.60  2.53  2.64  2.49       2.49    0.11
# 8   000017.SZ    20201106   2.49  2.48  2.52  2.38       2.48    0.01
# 9   000017.SZ    20201030   2.48  2.67  2.69  2.47       2.70   -0.22
# 10  000017.SZ    20201023   2.70  2.53  2.71  2.50       2.52    0.18
# 11  000017.SZ    20201016   2.52  2.49  2.57  2.49       2.45    0.07
# ...

# %%
def c = new CombinePlot(title:"US Treasuries", initWidth: 1000)
# Out:
#   File "<ipython-input-28-b25997dfa448>", line 1
#     def c = new CombinePlot(title:"US Treasuries", initWidth: 1000)
#           ^
# SyntaxError: invalid syntax

# %%
import plotly
import plotly.plotly as py
from plotly.graph_objs import *
plotly.tools.set_credentials_file(username="你的账号",api_key="你的API**")

trace0 = Scatter(
    x=[1,2,3,4,],
    y=[10,15,13,17]
)
trace1 = Scatter(
    x= [1,2,3,4],
    y= [16,5,11,9]
)
py.plot([trace0,trace1])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-23eb6d6ac568> in <module>
#       1 import plotly
# ----> 2 import plotly.plotly as py
#       3 from plotly.graph_objs import *
#       4 plotly.tools.set_credentials_file(username="你的账号",api_key="你的API**")
#       5
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/plotly/__init__.py in <module>
#       2 from _plotly_future_ import _chart_studio_error
#       3
# ----> 4 _chart_studio_error("plotly")
#
# ~/anaconda3/lib/python3.8/site-packages/_plotly_future_/__init__.py in _chart_studio_error(submodule)
#      41
#      42 def _chart_studio_error(submodule):
# ---> 43     raise ImportError(
#      44         """
#      45 The plotly.{submodule} module is deprecated,
#
# ImportError:
# The plotly.plotly module is deprecated,
# please install the chart-studio package and use the
# ...

# %%
import plotly

# %% [markdown]
# # ipywidgets

# %%
from ipywidgets import *

# %%
t1 = Text("text input", layout=Layout(
    width="80px", border="1px dashed red"
))
b1 = Button(description="button")
HBox((t1,b1))

# %%
b1.layout.border = "2px solid yellow"
t1.layout.border_left = "5px dotted blue"
b1.layout.border_right = "2px dotted blue"

# %%
t2 = Text("text input")
b2 = ToggleButton(description="toggle button", layout=Layout(
    width="200px", border_left="2px solid yellow"
))
HBox((t2,b2))

# %%
t2.layout.border_left = "5px dotted blue"
b2.layout.border_right = "2px dotted blue"
t2.layout.border = "1px dashed red"

# %%
t1.layout.border_top = "5px solid green"
b1.layout.border = "1px solid purple"
t2.layout.border_right = "5px double skyblue"

# %%
t2.layout.border_right = None
